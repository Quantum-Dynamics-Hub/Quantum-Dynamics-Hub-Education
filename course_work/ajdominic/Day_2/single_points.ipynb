# %%
import h5py

# %%
f = h5py.File('ethylene.hdf5','r')

# %%
f.keys()
# Out:
# <KeysViewHDF5 ['coefficients', 'cp2k', 'eigenvalues', 'energy']>

# %%
e_ao = f['eigenvalues/point_0'][()]

# %%
e_ao.shape
# Out:
# (10,)

# %%
e_ao
# Out:
# array([-0.5201369 , -0.42153352, -0.36150253, -0.3155685 , -0.23786467,
#        -0.03026853,  0.14950262,  0.15251653,  0.18642844,  0.26337734],
#       dtype=float32)

# %%
c_ao = f['coefficients/point_0'][()]

# %%
c_ao.shape
# Out:
# (46, 10)

# %%
c_ao
# Out:
# array([[ 3.58639300e-01, -2.91476521e-04,  1.74436681e-02,
#          6.02158427e-04,  3.08377537e-08, -8.37914271e-09,
#          3.45604308e-03,  1.05099156e-01,  5.10298014e-01,
#         -2.43511307e-03],
#        [ 2.81249383e-03,  1.01198866e-05,  9.59718414e-03,
#          1.04073406e-04, -5.30978861e-09,  8.84419915e-09,
#         -1.66990049e-03,  3.52247432e-02, -1.06797650e-01,
#          1.53145113e-03],
#        [-1.81579188e-01, -2.11388722e-01,  4.66405809e-01,
#         -2.00754896e-01,  6.93799507e-08,  3.87379302e-08,
#         -1.31639406e-01, -1.24642931e-01,  1.52894795e-01,
#         -1.58800393e-01],
#        [ 3.57519028e-08,  1.69629055e-09, -2.51462424e-08,
#          7.79482967e-09,  5.48525214e-01, -6.43296003e-01,
#         -1.53712030e-08, -3.52791005e-08,  4.64514294e-08,
#         -1.64755303e-08],
#        [-1.04100950e-01,  3.66839081e-01,  2.63589382e-01,
#          3.61500025e-01,  3.73805946e-08,  1.79095032e-08,
# ...
