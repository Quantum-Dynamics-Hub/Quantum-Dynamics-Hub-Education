# %%
import h5py

# %%
f = h5py.File('Ir-ppy-3.hdf5','r')

# %%
f.keys()
# Out:
# <KeysViewHDF5 ['coefficients', 'cp2k', 'eigenvalues']>

# %%
e_ao = f['eigenvalues/point_0'][()]

# %%
e_ao.shape
# Out:
# (240,)

# %%
e_ao
# Out:
# array([-3.4548078 , -1.9253811 , -1.9253676 , -1.9146913 , -0.8552848 ,
#        -0.85188496, -0.85148513, -0.72848827, -0.72723264, -0.72679603,
#        -0.70789766, -0.7065935 , -0.70606315, -0.67915183, -0.6785635 ,
#        -0.6784103 , -0.61975807, -0.6170882 , -0.6166154 , -0.6155282 ,
#        -0.613112  , -0.6126764 , -0.5530385 , -0.55248076, -0.55178475,
#        -0.54410607, -0.54067475, -0.5401963 , -0.4881872 , -0.48531246,
#        -0.48492372, -0.47932452, -0.4788988 , -0.47823742, -0.44918883,
#        -0.44205743, -0.44158715, -0.41105977, -0.41043118, -0.4102593 ,
#        -0.4026054 , -0.402025  , -0.4018131 , -0.3836783 , -0.3817469 ,
#        -0.38131374, -0.36216745, -0.3554343 , -0.35509083, -0.3509635 ,
#        -0.35083395, -0.34473425, -0.34356916, -0.34347075, -0.34274906,
#        -0.33629492, -0.33592352, -0.33378294, -0.32793936, -0.324843  ,
#        -0.3244443 , -0.30323598, -0.29874584, -0.29837126, -0.2897996 ,
# ...

# %%
# Out:
# <function ndarray.view>

# %%
c_ao = f['coefficients/point_0'][()]

# %%
c_ao.shape
# Out:
# (614, 240)

# %%
c_ao
# Out:
# array([[-9.9674934e-01,  6.8923869e-06, -4.1683343e-06, ...,
#          0.0000000e+00,  0.0000000e+00,  8.1695700e-43],
#        [-1.1600267e-01, -7.6097076e-06,  1.3222211e-05, ...,
#          0.0000000e+00,            inf,  0.0000000e+00],
#        [-3.9088768e-03, -2.0618985e-07, -2.9254795e-06, ...,
#          0.0000000e+00,  0.0000000e+00,  0.0000000e+00],
#        ...,
#        [ 1.5545485e-05,  3.7859893e-06,  2.7922606e-06, ...,
#          0.0000000e+00,  8.1555571e-43,  8.6039726e-43],
#        [-1.1620576e-05, -1.8509530e-06, -3.2299384e-05, ...,
#          0.0000000e+00,  0.0000000e+00,  0.0000000e+00],
#        [ 2.1455300e-05,  7.4145937e-06, -1.1201653e-05, ...,
#          0.0000000e+00,  0.0000000e+00,  0.0000000e+00]], dtype=float32)
